# %%
from rateslib import *

# %% [markdown]
# # Benchmarks in local version

# %%
# %timeit get_calendar("ldn")
# Out:
# 336 μs ± 1.66 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit get_calendar("ldn,tgt")
# Out:
# 600 μs ± 7.27 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
from rateslib.rs import get_named_calendar

# %%
# %timeit get_named_calendar("ldn")
# Out:
# 335 μs ± 1.99 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit get_calendar("ldn,tgt", named=False)
# Out:
# 4.74 μs ± 40.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit NamedCal("ldn,tgt")
# Out:
# 597 μs ± 1.27 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit get_calendar("ldn,tgt", named=True)
# Out:
# 597 μs ± 462 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
